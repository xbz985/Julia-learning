# %%
v = [1, 2, 3]
println("列向量 v:",v)
# Out:
# 列向量 v:[1, 2, 3]

# %%
# 矩阵Matrix
A = [
    1 2 3;
    4 5 6
]
println("矩阵A的尺寸：", size(A))
# Out:
# 矩阵A的尺寸：(2, 3)

# %%
println("矩阵A的第一个元素是：",A[1,1])
# Out:
# 矩阵A的第一个元素是：1

# %%
# 取第二行的所有列
row_2 = A[2,:]
row_2
# Out:
# 3-element Vector{Int64}:
#  4
#  5
#  6

# %%
# 广播机制
x = [
    2 3 5;
    4 7 9
]
# 对单个数应用函数
f(a) = a^2 + 1

y = f.(x) # 把f应用到x的每一个数上
println("广播计算结果：", y)
# Out:
# 广播计算结果：[5 10 26; 17 50 82]

# %%
v1 = [1, 2 , 3]
v2 = [7, 8, 9]
prod = v1 .* v2 # .* 对应元素相乘
prod
# Out:
# 3-element Vector{Int64}:
#   7
#  16
#  27

# %%
println(prod)
# Out:
# [7, 16, 27]
